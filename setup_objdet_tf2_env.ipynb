# %% [markdown]
# # TensorFlow2 Object Detection Env Creating
# ---
# - This install procedure is reference from [here](https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html), which has more detail, but this notebook help you create this env more easily.
# - pycocotool & object-detection need to be installed individually.

# %% [markdown]
# # Download the `tf2_object_detection_nu`
# ---
# - What this directory looks like:
# - <pre>tf2_object_detection_nu/
# ├─ image_dataset/
# |    └─...
# ├─ models/
# |    └─...
# ├─ preTrainModelUsed/
# |    └─...
# ├─ tool/
# |    └─...
# ├─ workspace/
# |    └─...
# ├─ setup_objdet_tf1_env.ipynb
# ├─ setup_objdet_tf2_env.ipynb (*we are here)
# ├─ tf1_cpu.yml
# ├─ tf2_cpu.yml
# └─ ...
# </pre>
# - (IMPORTANT) Please remain this notebook at the original directory sequence, because the following commands need the relative location.

# %% [markdown]
# ## TensorFlow Model Garden
# - If you are opening this notebook, you should already download this object detection api. You can skip this step.
# - TensorFlow Model Garden is already prepared in this directory.

# %% [markdown]
# ## Alternative way to download newest TensorFlow Model Garden
# - How to download and prepare it from Google's tutorial is [here](https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html#downloading-the-tensorflow-model-garden). After you download finish, replace the `models/` as new one.

# %% [markdown]
# # Create Tensorflow object detection env
# ---

# %% [markdown]
# ## Create an Env
# - Create a virtual env and preinstall some needed libraries at once.

# %%
# !conda env create -f tf2_cpu.yml
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\ProgramData\\Anaconda3\\envs\\obj_det_tf2_cpu\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'C:\\Users\\CYCHEN38\\image_detection\\setup_test\\tf2_object_detection_nu\\condaenv.hi_mt6v9.requirements.txt']
# Pip subprocess output:
# Collecting absl-py==1.2.0
#
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
#
# Collecting aiofiles==22.1.0
#
#   Using cached aiofiles-22.1.0-py3-none-any.whl (14 kB)
#
# Collecting apache-beam==2.41.0
#
#   Using cached apache_beam-2.41.0-cp38-cp38-win_amd64.whl (4.3 MB)
#
# Collecting argcomplete==2.0.0
#
#   Using cached argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
#
# Collecting astunparse==1.6.3
#
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
#
# Collecting avro-python3==1.10.2
#
#   Using cached avro_python3-1.10.2-py3-none-any.whl
#
# Collecting backports-cached-property==1.0.2
#
#   Using cached backports.cached_property-1.0.2-py3-none-any.whl (6.1 kB)
#
# Collecting backports-zoneinfo==0.2.1
#
#   Using cached backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
#
# Collecting boto3==1.24.83
#
#   Using cached boto3-1.24.83-py3-none-any.whl (132 kB)
#
# Collecting botocore==1.27.83
#
#   Using cached botocore-1.27.83-py3-none-any.whl (9.2 MB)
#
# Collecting cachetools==5.2.0
#
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
#
# Requirement already satisfied: certifi==2022.9.24 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from -r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 12)) (2022.9.24)
#
# Collecting click==8.1.3
#
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
#
# Collecting cloudpickle==2.2.0
#
#   Using cached cloudpickle-2.2.0-py3-none-any.whl (25 kB)
#
# Collecting contextlib2==21.6.0
#
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
#
# Collecting contourpy==1.0.5
#
#   Using cached contourpy-1.0.5-cp38-cp38-win_amd64.whl (164 kB)
#
# Collecting crcmod==1.7
#
#   Using cached crcmod-1.7-cp38-cp38-win_amd64.whl
#
# Collecting cycler==0.11.0
#
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
#
# Collecting cython==0.29.32
#
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#
# Collecting dacite==1.6.0
#
#   Using cached dacite-1.6.0-py3-none-any.whl (12 kB)
#
# Collecting deprecated==1.2.13
#
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
#
# Collecting dill==0.3.1.1
#
#   Using cached dill-0.3.1.1-py3-none-any.whl
#
# Collecting dm-tree==0.1.7
#
#   Using cached dm_tree-0.1.7-cp38-cp38-win_amd64.whl (91 kB)
#
# Collecting dnspython==2.2.1
#
#   Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
#
# Collecting docopt==0.6.2
#
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
#
# Collecting etils==0.8.0
#
#   Using cached etils-0.8.0-py3-none-any.whl (127 kB)
#
# Collecting eventlet==0.33.1
#
#   Using cached eventlet-0.33.1-py2.py3-none-any.whl (226 kB)
#
# Collecting fastavro==1.6.1
#
#   Using cached fastavro-1.6.1-cp38-cp38-win_amd64.whl (446 kB)
#
# Collecting fiftyone==0.17.2
#
#   Using cached fiftyone-0.17.2-py3-none-any.whl (2.2 MB)
#
# Collecting fiftyone-brain==0.9.1
#
#   Using cached fiftyone_brain-0.9.1-py3-none-any.whl (47 kB)
#
# Collecting fiftyone-db==0.3.0
#
#   Using cached fiftyone_db-0.3.0-py3-none-win_amd64.whl (16.6 MB)
#
# Collecting flatbuffers==22.9.24
#
#   Using cached flatbuffers-22.9.24-py2.py3-none-any.whl (26 kB)
#
# Collecting fonttools==4.37.3
#
#   Using cached fonttools-4.37.3-py3-none-any.whl (959 kB)
#
# Collecting future==0.18.2
#
#   Using cached future-0.18.2-py3-none-any.whl
#
# Collecting gast==0.4.0
#
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
#
# Collecting gin-config==0.5.0
#
#   Using cached gin_config-0.5.0-py3-none-any.whl (61 kB)
#
# Collecting glob2==0.7
#
#   Using cached glob2-0.7-py2.py3-none-any.whl
#
# Collecting google-api-core==2.8.2
#
#   Using cached google_api_core-2.8.2-py3-none-any.whl (114 kB)
#
# Collecting google-api-python-client==2.63.0
#
#   Using cached google_api_python_client-2.63.0-py2.py3-none-any.whl (9.3 MB)
#
# Collecting google-auth==2.12.0
#
#   Using cached google_auth-2.12.0-py2.py3-none-any.whl (169 kB)
#
# Collecting google-auth-httplib2==0.1.0
#
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
#
# Collecting google-auth-oauthlib==0.4.6
#
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
#
# Collecting google-pasta==0.2.0
#
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
#
# Collecting googleapis-common-protos==1.56.4
#
#   Using cached googleapis_common_protos-1.56.4-py2.py3-none-any.whl (211 kB)
#
# Collecting graphql-core==3.1.7
#
#   Using cached graphql_core-3.1.7-py3-none-any.whl (189 kB)
#
# Collecting greenlet==1.1.3
#
#   Using cached greenlet-1.1.3-cp38-cp38-win_amd64.whl (101 kB)
#
# Collecting grpcio==1.34.1
#
#   Using cached grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
#
# Collecting h11==0.12.0
#
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
#
# Collecting h2==4.1.0
#
#   Using cached h2-4.1.0-py3-none-any.whl (57 kB)
#
# Collecting h5py==3.1.0
#
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
#
# Collecting hdfs==2.7.0
#
#   Using cached hdfs-2.7.0-py3-none-any.whl (34 kB)
#
# Collecting hpack==4.0.0
#
#   Using cached hpack-4.0.0-py3-none-any.whl (32 kB)
#
# Collecting httpcore==0.15.0
#
#   Using cached httpcore-0.15.0-py3-none-any.whl (68 kB)
#
# Collecting httplib2==0.20.4
#
#   Using cached httplib2-0.20.4-py3-none-any.whl (96 kB)
#
# Collecting httpx==0.23.0
#
#   Using cached httpx-0.23.0-py3-none-any.whl (84 kB)
#
# Collecting hypercorn==0.14.3
#
#   Using cached Hypercorn-0.14.3-py3-none-any.whl (57 kB)
#
# Collecting hyperframe==6.0.1
#
#   Using cached hyperframe-6.0.1-py3-none-any.whl (12 kB)
#
# Requirement already satisfied: idna==3.4 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from -r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 58)) (3.4)
#
# Collecting imageio==2.22.0
#
#   Using cached imageio-2.22.0-py3-none-any.whl (3.4 MB)
#
# Collecting immutabledict==2.2.1
#
#   Using cached immutabledict-2.2.1-py3-none-any.whl (4.0 kB)
#
# Collecting importlib-metadata==4.12.0
#
#   Using cached importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
#
# Collecting ipyfilechooser==0.6.0
#
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
#
# Collecting ipywidgets==8.0.2
#
#   Using cached ipywidgets-8.0.2-py3-none-any.whl (134 kB)
#
# Collecting jmespath==1.0.1
#
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
#
# Collecting joblib==1.2.0
#
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
#
# Collecting jupyterlab-widgets==3.0.3
#
#   Using cached jupyterlab_widgets-3.0.3-py3-none-any.whl (384 kB)
#
# Collecting kaggle==1.5.12
#
#   Using cached kaggle-1.5.12-py3-none-any.whl
#
# Collecting kaleido==0.2.1
#
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#
# Collecting keras==2.10.0
#
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#
# Collecting keras-nightly==2.5.0.dev2021032900
#
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#
# Collecting keras-preprocessing==1.1.2
#
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#
# Collecting kiwisolver==1.4.4
#
#   Using cached kiwisolver-1.4.4-cp38-cp38-win_amd64.whl (55 kB)
#
# Collecting labelimg==1.8.6
#
#   Using cached labelImg-1.8.6-py2.py3-none-any.whl
#
# Collecting libclang==14.0.6
#
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
#
# Collecting lvis==0.5.3
#
#   Using cached lvis-0.5.3-py3-none-any.whl (14 kB)
#
# Collecting lxml==4.9.1
#
#   Using cached lxml-4.9.1-cp38-cp38-win_amd64.whl (3.6 MB)
#
# Collecting markdown==3.4.1
#
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
#
# Collecting matplotlib==3.6.0
#
#   Using cached matplotlib-3.6.0-cp38-cp38-win_amd64.whl (7.2 MB)
#
# Collecting mongoengine==0.20.0
#
#   Using cached mongoengine-0.20.0-py3-none-any.whl (106 kB)
#
# Collecting motor==2.5.1
#
#   Using cached motor-2.5.1-py3-none-any.whl (55 kB)
#
# Collecting ndjson==0.3.1
#
#   Using cached ndjson-0.3.1-py2.py3-none-any.whl (5.3 kB)
#
# Collecting networkx==2.8.6
#
#   Using cached networkx-2.8.6-py3-none-any.whl (2.0 MB)
#
# Collecting numpy==1.22.4
#
#   Using cached numpy-1.22.4-cp38-cp38-win_amd64.whl (14.8 MB)
#
# Collecting oauth2client==4.1.3
#
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#
# Collecting oauthlib==3.2.1
#
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
#
# Collecting opencv-python==4.6.0.66
#
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#
# Collecting opencv-python-headless==4.5.5.64
#
#   Using cached opencv_python_headless-4.5.5.64-cp36-abi3-win_amd64.whl (35.3 MB)
#
# Collecting opt-einsum==3.3.0
#
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#
# Collecting orjson==3.8.0
#
#   Using cached orjson-3.8.0-cp38-none-win_amd64.whl (197 kB)
#
# Collecting pandas==1.5.0
#
#   Using cached pandas-1.5.0-cp38-cp38-win_amd64.whl (11.0 MB)
#
# Collecting patool==1.12
#
#   Using cached patool-1.12-py2.py3-none-any.whl (77 kB)
#
# Collecting pillow==9.2.0
#
#   Using cached Pillow-9.2.0-cp38-cp38-win_amd64.whl (3.3 MB)
#
# Collecting plotly==5.10.0
#
#   Using cached plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
#
# Collecting portalocker==2.5.1
#
#   Using cached portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
#
# Collecting pprintpp==0.4.0
#
#   Using cached pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
#
# Collecting priority==2.0.0
#
#   Using cached priority-2.0.0-py3-none-any.whl (8.9 kB)
#
# Collecting promise==2.3
#
#   Using cached promise-2.3-py3-none-any.whl
#
# Collecting proto-plus==1.22.1
#
#   Using cached proto_plus-1.22.1-py3-none-any.whl (47 kB)
#
# Collecting protobuf==3.19.5
#
#   Using cached protobuf-3.19.5-cp38-cp38-win_amd64.whl (896 kB)
#
# Collecting py-cpuinfo==8.0.0
#
#   Using cached py_cpuinfo-8.0.0-py3-none-any.whl
#
# Collecting py-setenv==1.1.0
#
#   Downloading py_setenv-1.1.0.tar.gz (3.5 kB)
#
#   Preparing metadata (setup.py): started
#
#   Preparing metadata (setup.py): finished with status 'done'
#
# Collecting pyarrow==7.0.0
#
#   Using cached pyarrow-7.0.0-cp38-cp38-win_amd64.whl (16.1 MB)
#
# Collecting pyasn1==0.4.8
#
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#
# Collecting pyasn1-modules==0.2.8
#
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#
# Collecting pydot==1.4.2
#
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
#
# Collecting pymongo==3.12.3
#
#   Using cached pymongo-3.12.3-cp38-cp38-win_amd64.whl (398 kB)
#
# Collecting pyparsing==2.4.7
#
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#
# Collecting pyqt5==5.15.7
#
#   Using cached PyQt5-5.15.7-cp37-abi3-win_amd64.whl (6.8 MB)
#
# Collecting pyqt5-qt5==5.15.2
#
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#
# Collecting pyqt5-sip==12.11.0
#
#   Using cached PyQt5_sip-12.11.0-cp38-cp38-win_amd64.whl (78 kB)
#
# Collecting python-multipart==0.0.5
#
#   Using cached python_multipart-0.0.5-py3-none-any.whl
#
# Collecting python-slugify==6.1.2
#
#   Using cached python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
#
# Collecting pytz-deprecation-shim==0.1.0.post0
#
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
#
# Collecting pywavelets==1.4.1
#
#   Using cached PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
#
# Collecting pyyaml==5.4.1
#
#   Using cached PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
#
# Collecting regex==2022.9.13
#
#   Using cached regex-2022.9.13-cp38-cp38-win_amd64.whl (267 kB)
#
# Collecting requests-oauthlib==1.3.1
#
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
#
# Collecting retrying==1.3.3
#
#   Using cached retrying-1.3.3-py3-none-any.whl
#
# Collecting rfc3986==1.5.0
#
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
#
# Collecting rsa==4.9
#
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
#
# Collecting s3transfer==0.6.0
#
#   Using cached s3transfer-0.6.0-py3-none-any.whl (79 kB)
#
# Collecting sacrebleu==2.2.0
#
#   Using cached sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#
# Collecting scikit-image==0.19.3
#
#   Using cached scikit_image-0.19.3-cp38-cp38-win_amd64.whl (12.2 MB)
#
# Collecting scikit-learn==1.1.2
#
#   Using cached scikit_learn-1.1.2-cp38-cp38-win_amd64.whl (7.3 MB)
#
# Collecting scipy==1.9.1
#
#   Using cached scipy-1.9.1-cp38-cp38-win_amd64.whl (38.6 MB)
#
# Collecting sentencepiece==0.1.97
#
#   Using cached sentencepiece-0.1.97-cp38-cp38-win_amd64.whl (1.1 MB)
#
# Collecting sentinel==0.3.0
#
#   Using cached sentinel-0.3.0-py3-none-any.whl (6.0 kB)
#
# Collecting seqeval==1.2.2
#
#   Using cached seqeval-1.2.2-py3-none-any.whl
#
# Collecting setuptools==65.4.0
#
#   Using cached setuptools-65.4.0-py3-none-any.whl (1.2 MB)
#
# Collecting six==1.15.0
#
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
#
# Collecting sortedcontainers==2.4.0
#
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
#
# Collecting sse-starlette==0.10.3
#
#   Using cached sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
#
# Collecting sseclient-py==1.7.2
#
#   Using cached sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
#
# Collecting starlette==0.16.0
#
#   Using cached starlette-0.16.0-py3-none-any.whl (61 kB)
#
# Collecting strawberry-graphql==0.96.0
#
#   Using cached strawberry_graphql-0.96.0-py3-none-any.whl (135 kB)
#
# Collecting tabulate==0.8.10
#
#   Using cached tabulate-0.8.10-py3-none-any.whl (29 kB)
#
# Collecting tenacity==8.1.0
#
#   Using cached tenacity-8.1.0-py3-none-any.whl (23 kB)
#
# Collecting tensorboard==2.10.1
#
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#
# Collecting tensorboard-data-server==0.6.1
#
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
#
# Collecting tensorboard-plugin-wit==1.8.1
#
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#
# Collecting tensorflow==2.10.0
#
#   Using cached tensorflow-2.10.0-cp38-cp38-win_amd64.whl (455.9 MB)
#
# Collecting tensorflow-addons==0.18.0
#
#   Using cached tensorflow_addons-0.18.0-cp38-cp38-win_amd64.whl (765 kB)
#
# Collecting tensorflow-datasets==4.6.0
#
#   Using cached tensorflow_datasets-4.6.0-py3-none-any.whl (4.3 MB)
#
# Collecting tensorflow-estimator==2.10.0
#
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#
# Collecting tensorflow-hub==0.12.0
#
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#
# Collecting tensorflow-io==0.27.0
#
#   Using cached tensorflow_io-0.27.0-cp38-cp38-win_amd64.whl (22.9 MB)
#
# Collecting tensorflow-io-gcs-filesystem==0.27.0
#
#   Using cached tensorflow_io_gcs_filesystem-0.27.0-cp38-cp38-win_amd64.whl (1.5 MB)
#
# Collecting tensorflow-metadata==1.10.0
#
#   Using cached tensorflow_metadata-1.10.0-py3-none-any.whl (50 kB)
#
# Collecting tensorflow-model-optimization==0.7.3
#
#   Using cached tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#
# Collecting tensorflow-text==2.10.0
#
#   Using cached tensorflow_text-2.10.0-cp38-cp38-win_amd64.whl (5.0 MB)
#
# Collecting termcolor==1.1.0
#
#   Using cached termcolor-1.1.0-py3-none-any.whl
#
# Collecting text-unidecode==1.3
#
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#
# Collecting tf-slim==1.1.0
#
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#
# Collecting threadpoolctl==3.1.0
#
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
#
# Collecting tifffile==2022.8.12
#
#   Using cached tifffile-2022.8.12-py3-none-any.whl (208 kB)
#
# Collecting toml==0.10.2
#
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
#
# Collecting tqdm==4.64.1
#
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#
# Collecting typeguard==2.13.3
#
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
#
# Collecting typing-extensions==3.7.4.3
#
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
#
# Collecting tzdata==2022.4
#
#   Using cached tzdata-2022.4-py2.py3-none-any.whl (336 kB)
#
# Collecting tzlocal==4.2
#
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
#
# Collecting universal-analytics-python3==1.1.1
#
#   Using cached universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
#
# Collecting uritemplate==4.1.1
#
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
#
# Requirement already satisfied: urllib3==1.26.12 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from -r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 164)) (1.26.12)
#
# Collecting voxel51-eta==0.8.1
#
#   Using cached voxel51_eta-0.8.1-py2.py3-none-any.whl (564 kB)
#
# Collecting werkzeug==2.2.2
#
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#
# Requirement already satisfied: wheel==0.37.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from -r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 167)) (0.37.1)
#
# Collecting widgetsnbextension==4.0.3
#
#   Using cached widgetsnbextension-4.0.3-py3-none-any.whl (2.0 MB)
#
# Collecting wrapt==1.12.1
#
#   Using cached wrapt-1.12.1-cp38-cp38-win_amd64.whl
#
# Collecting wsproto==1.2.0
#
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
#
# Collecting xmltodict==0.13.0
#
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
#
# Collecting zipp==3.8.1
#
#   Using cached zipp-3.8.1-py3-none-any.whl (5.6 kB)
#
# Requirement already satisfied: pytz>=2018.3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam==2.41.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 3)) (2022.1)
#
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam==2.41.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 3)) (2.28.1)
#
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam==2.41.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 3)) (2.8.2)
#
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from click==8.1.3->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 13)) (0.4.5)
#
# Requirement already satisfied: Jinja2>=3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from fiftyone==0.17.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 29)) (3.0.3)
#
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from fiftyone==0.17.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 29)) (21.3)
#
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from fiftyone==0.17.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 29)) (5.9.0)
#
# Requirement already satisfied: anyio==3.* in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from httpcore==0.15.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 53)) (3.5.0)
#
# Requirement already satisfied: sniffio==1.* in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from httpcore==0.15.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 53)) (1.2.0)
#
# Requirement already satisfied: traitlets>=4.3.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (5.1.1)
#
# Requirement already satisfied: ipython>=6.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (8.4.0)
#
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (6.15.2)
#
# Requirement already satisfied: pywin32>=226 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from portalocker==2.5.1->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 94)) (302)
#
# Requirement already satisfied: pygments<3.0,>=2.3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from strawberry-graphql==0.96.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 135)) (2.11.2)
#
# Requirement already satisfied: importlib-resources in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets==4.6.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 143)) (5.2.0)
#
# Collecting etils[epath]
#
#   Using cached etils-0.9.0-py3-none-any.whl (140 kB)
#
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from werkzeug==2.2.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 166)) (2.1.1)
#
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (7.3.5)
#
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (1.5.5)
#
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (6.2)
#
# Requirement already satisfied: debugpy>=1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (1.5.1)
#
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (23.2.0)
#
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.1.6)
#
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (3.0.20)
#
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.2.0)
#
# Requirement already satisfied: backcall in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.2.0)
#
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.7.5)
#
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (5.1.1)
#
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.18.1)
#
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam==2.41.0->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 3)) (2.0.4)
#
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.8.3)
#
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.4)
#
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (4.10.0)
#
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.2.5)
#
# Requirement already satisfied: executing in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.8.3)
#
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (2.0.5)
#
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.0.2->-r C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\condaenv.hi_mt6v9.requirements.txt (line 63)) (0.2.2)
#
# Building wheels for collected packages: py-setenv
#
#   Building wheel for py-setenv (setup.py): started
#
#   Building wheel for py-setenv (setup.py): finished with status 'done'
#
#   Created wheel for py-setenv: filename=py_setenv-1.1.0-py3-none-any.whl size=3529 sha256=ad4ea751c202140fd1a3713b1c9f1e95e523692139c24441741fb055315123c4
#
#   Stored in directory: c:\users\cychen38\appdata\local\pip\cache\wheels\7f\0d\54\a64b772cfe22d693e7f1c69434c3f71697c2b6e57cb085c2b9
#
# Successfully built py-setenv
#
# Installing collected packages: wrapt, typing-extensions, text-unidecode, termcolor, tensorboard-plugin-wit, sseclient-py, sortedcontainers, sentencepiece, rfc3986, pyqt5-qt5, pyasn1, py-cpuinfo, pprintpp, patool, ndjson, libclang, keras-nightly, keras, kaleido, glob2, gin-config, flatbuffers, docopt, dm-tree, crcmod, zipp, xmltodict, widgetsnbextension, werkzeug, uritemplate, tzdata, typeguard, tqdm, toml, threadpoolctl, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, tenacity, tabulate, six, setuptools, sentinel, rsa, regex, pyyaml, python-slugify, pyqt5-sip, pyparsing, pymongo, pyasn1-modules, protobuf, priority, portalocker, pillow, orjson, oauthlib, numpy, networkx, lxml, kiwisolver, jupyterlab-widgets, joblib, jmespath, immutabledict, hyperframe, hpack, h11, greenlet, graphql-core, gast, future, fonttools, fiftyone-db, fastavro, etils, dnspython, dill, deprecated, dacite, cython, cycler, contextlib2, cloudpickle, click, cachetools, backports-zoneinfo, backports-cached-property, avro-python3, argcomplete, aiofiles, absl-py, wsproto, tifffile, tf-slim, tensorflow-model-optimization, tensorflow-io, tensorflow-hub, starlette, scipy, sacrebleu, retrying, requests-oauthlib, pywavelets, pytz-deprecation-shim, python-multipart, pyqt5, pydot, pyarrow, py-setenv, proto-plus, promise, plotly, opt-einsum, opencv-python-headless, opencv-python, motor, mongoengine, keras-preprocessing, importlib-metadata, imageio, httplib2, httpcore, hdfs, h5py, h2, grpcio, googleapis-common-protos, google-pasta, google-auth, eventlet, contourpy, astunparse, tzlocal, tensorflow-metadata, tensorflow-addons, strawberry-graphql, sse-starlette, scikit-learn, scikit-image, pandas, oauth2client, matplotlib, markdown, labelimg, kaggle, hypercorn, httpx, google-auth-oauthlib, google-auth-httplib2, google-api-core, botocore, apache-beam, voxel51-eta, universal-analytics-python3, tensorflow-datasets, tensorboard, seqeval, s3transfer, lvis, google-api-python-client, fiftyone-brain, tensorflow, boto3, tensorflow-text, ipywidgets, fiftyone, ipyfilechooser
#
#   Attempting uninstall: typing-extensions
#
#     Found existing installation: typing_extensions 4.3.0
#
#     Uninstalling typing_extensions-4.3.0:
#
#       Successfully uninstalled typing_extensions-4.3.0
#
#   Attempting uninstall: zipp
#
#     Found existing installation: zipp 3.8.0
#
#     Uninstalling zipp-3.8.0:
#
#       Successfully uninstalled zipp-3.8.0
#
#   Attempting uninstall: six
#
#     Found existing installation: six 1.16.0
#
#     Uninstalling six-1.16.0:
#
#       Successfully uninstalled six-1.16.0
#
#   Attempting uninstall: setuptools
#
#     Found existing installation: setuptools 65.5.0
#
#     Uninstalling setuptools-65.5.0:
#
#       Successfully uninstalled setuptools-65.5.0
#
#   Attempting uninstall: pyparsing
#
#     Found existing installation: pyparsing 3.0.9
#
#     Uninstalling pyparsing-3.0.9:
#
#       Successfully uninstalled pyparsing-3.0.9
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 1.23.1
#
#     Uninstalling numpy-1.23.1:
#
#       Successfully uninstalled numpy-1.23.1
#
# Successfully installed absl-py-1.2.0 aiofiles-22.1.0 apache-beam-2.41.0 argcomplete-2.0.0 astunparse-1.6.3 avro-python3-1.10.2 backports-cached-property-1.0.2 backports-zoneinfo-0.2.1 boto3-1.24.83 botocore-1.27.83 cachetools-5.2.0 click-8.1.3 cloudpickle-2.2.0 contextlib2-21.6.0 contourpy-1.0.5 crcmod-1.7 cycler-0.11.0 cython-0.29.32 dacite-1.6.0 deprecated-1.2.13 dill-0.3.1.1 dm-tree-0.1.7 dnspython-2.2.1 docopt-0.6.2 etils-0.8.0 eventlet-0.33.1 fastavro-1.6.1 fiftyone-0.17.2 fiftyone-brain-0.9.1 fiftyone-db-0.3.0 flatbuffers-22.9.24 fonttools-4.37.3 future-0.18.2 gast-0.4.0 gin-config-0.5.0 glob2-0.7 google-api-core-2.8.2 google-api-python-client-2.63.0 google-auth-2.12.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 googleapis-common-protos-1.56.4 graphql-core-3.1.7 greenlet-1.1.3 grpcio-1.34.1 h11-0.12.0 h2-4.1.0 h5py-3.1.0 hdfs-2.7.0 hpack-4.0.0 httpcore-0.15.0 httplib2-0.20.4 httpx-0.23.0 hypercorn-0.14.3 hyperframe-6.0.1 imageio-2.22.0 immutabledict-2.2.1 importlib-metadata-4.12.0 ipyfilechooser-0.6.0 ipywidgets-8.0.2 jmespath-1.0.1 joblib-1.2.0 jupyterlab-widgets-3.0.3 kaggle-1.5.12 kaleido-0.2.1 keras-2.10.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 kiwisolver-1.4.4 labelimg-1.8.6 libclang-14.0.6 lvis-0.5.3 lxml-4.9.1 markdown-3.4.1 matplotlib-3.6.0 mongoengine-0.20.0 motor-2.5.1 ndjson-0.3.1 networkx-2.8.6 numpy-1.22.4 oauth2client-4.1.3 oauthlib-3.2.1 opencv-python-4.6.0.66 opencv-python-headless-4.5.5.64 opt-einsum-3.3.0 orjson-3.8.0 pandas-1.5.0 patool-1.12 pillow-9.2.0 plotly-5.10.0 portalocker-2.5.1 pprintpp-0.4.0 priority-2.0.0 promise-2.3 proto-plus-1.22.1 protobuf-3.19.5 py-cpuinfo-8.0.0 py-setenv-1.1.0 pyarrow-7.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydot-1.4.2 pymongo-3.12.3 pyparsing-2.4.7 pyqt5-5.15.7 pyqt5-qt5-5.15.2 pyqt5-sip-12.11.0 python-multipart-0.0.5 python-slugify-6.1.2 pytz-deprecation-shim-0.1.0.post0 pywavelets-1.4.1 pyyaml-5.4.1 regex-2022.9.13 requests-oauthlib-1.3.1 retrying-1.3.3 rfc3986-1.5.0 rsa-4.9 s3transfer-0.6.0 sacrebleu-2.2.0 scikit-image-0.19.3 scikit-learn-1.1.2 scipy-1.9.1 sentencepiece-0.1.97 sentinel-0.3.0 seqeval-1.2.2 setuptools-65.4.0 six-1.15.0 sortedcontainers-2.4.0 sse-starlette-0.10.3 sseclient-py-1.7.2 starlette-0.16.0 strawberry-graphql-0.96.0 tabulate-0.8.10 tenacity-8.1.0 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-addons-0.18.0 tensorflow-datasets-4.6.0 tensorflow-estimator-2.10.0 tensorflow-hub-0.12.0 tensorflow-io-0.27.0 tensorflow-io-gcs-filesystem-0.27.0 tensorflow-metadata-1.10.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.10.0 termcolor-1.1.0 text-unidecode-1.3 tf-slim-1.1.0 threadpoolctl-3.1.0 tifffile-2022.8.12 toml-0.10.2 tqdm-4.64.1 typeguard-2.13.3 typing-extensions-3.7.4.3 tzdata-2022.4 tzlocal-4.2 universal-analytics-python3-1.1.1 uritemplate-4.1.1 voxel51-eta-0.8.1 werkzeug-2.2.2 widgetsnbextension-4.0.3 wrapt-1.12.1 wsproto-1.2.0 xmltodict-0.13.0 zipp-3.8.1
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate obj_det_tf2_cpu
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# ## Active this new env
# - Close this JupyterLab now.
# - Choose the new env as below picture.
# - Open again the JupyterLab, and now you can run program in this new `obj_det_tf2_cpu` env.
# - <img src="tool/choose_new_env.png" width="800" height="500">

# %% [markdown]
# ## Test Tensorflow
# - Please excute the block below

# %%
import tensorflow as tf

print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(-2704.0715, shape=(), dtype=float32)

# %% [markdown]
# # Protobuf Installation
# ---
# - If you have already installed `setup_object_tf1_env.ipynb`, skip Protobuf step.
# - This script includs:
#     - Download `protoc-21.9-win64.zip`, extract, and create folders.
#     - Set Environment Variable.
#     - Compile Protobuf in `models/research/`

# %%
# !python protobuf_setup.py
# Out:
# ================================
# == Protobuf Installation step ==
# ================================
# create folder finish!
# download finish!
# Start to extract: C:\Program Files\Google Protobuf\protoc-21.9-win64.zip
# extract finish!
# True
# New working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\models\research
# compile protobuf
# Change back working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu
# 0it [00:00, ?it/s]
# 100it [00:00, 976.83it/s]
# 244it [00:00, 1189.92it/s]
# 754it [00:00, 2900.82it/s]
# 1783it [00:00, 5744.41it/s]
# 2223it [00:00, 4914.96it/s]

# %% [markdown]
# # COCO API installation
# ---
# - This script includs:
#     - Add Environment Variable
#     - Pip install coco API
#     - Update an issue python file in coco package

# %% [markdown]
# ## Install coco API

# %%
# !python cocoapi_setup.py
# Out:
# ================================
# == COCOAPI Installation step ==
# ================================
# True
# install_cocoAPI
# Collecting git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/philferriere/cocoapi.git to c:\users\cychen38\appdata\local\temp\pip-req-build-3z0xtstn
#   Resolved https://github.com/philferriere/cocoapi.git to commit 2929bd2ef6b451054755dfd7ceb09278f935f7ad
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py): started
#   Building wheel for pycocotools (setup.py): finished with status 'done'
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp38-cp38-win_amd64.whl size=73419 sha256=8e1fe291d96c4cd08f9f53776b28c1d679c55c430862170488282af42979cf2c
#   Stored in directory: C:\Users\CYCHEN38\AppData\Local\Temp\pip-ephem-wheel-cache-3tifxc26\wheels\bd\1c\0d\8c82e1b9bc855b82e1eb53eadea4459efe171d2daf5a222701
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0
#   Running command git clone --filter=blob:none --quiet https://github.com/philferriere/cocoapi.git 'C:\Users\CYCHEN38\AppData\Local\Temp\pip-req-build-3z0xtstn'

# %% [markdown]
# # Install the Object Detection API
# ---

# %%
# !python obj_det_api_setup.py --fix_protobuf_builder
# Out:
# ======================================
# == Install the Object Detection API ==
# ======================================
# fix pycocotools cocoeval.py
# Current working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu
# New working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\models\research
# Processing c:\users\cychen38\image_detection\setup_test\tf2_object_detection_nu\models\research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: avro-python3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (2.41.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (9.2.0)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (3.6.0)
# Requirement already satisfied: Cython in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (2.0)
# Requirement already satisfied: lvis in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (1.9.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (1.5.0)
# Collecting tf-models-official>=2.5.1
#   Using cached tf_models_official-2.11.0-py2.py3-none-any.whl (2.3 MB)
# Requirement already satisfied: tensorflow_io in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (0.27.0)
# Requirement already satisfied: keras in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (2.10.0)
# Requirement already satisfied: pyparsing==2.4.7 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.5)
# Requirement already satisfied: tabulate>=0.8.9 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Requirement already satisfied: portalocker in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.5.1)
# Requirement already satisfied: regex in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.9.13)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting opencv-python-headless==4.5.2.52
#   Using cached opencv_python_headless-4.5.2.52-cp38-cp38-win_amd64.whl (34.6 MB)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (8.0.0)
# Collecting tf-models-official>=2.5.1
#   Using cached tf_models_official-2.10.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: tensorflow-text~=2.10.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.10.0)
# Requirement already satisfied: tensorflow-datasets in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.3)
# Requirement already satisfied: opencv-python-headless in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.5.5.64)
# Requirement already satisfied: gin-config in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: seqeval in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.1)
# Requirement already satisfied: immutabledict in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.2.1)
# Requirement already satisfied: oauth2client in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: tensorflow-addons in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.18.0)
# Requirement already satisfied: tensorflow~=2.10.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.10.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.63.0)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.97)
# Requirement already satisfied: kaggle>=1.3.9 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: psutil>=5.4.3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from pandas->object-detection==0.1) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: absl-py>=0.2.2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tf-slim->object-detection==0.1) (1.2.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (1.22.1)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (2.28.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (1.6.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (3.7.4.3)
# Requirement already satisfied: cloudpickle<3,>=2.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (2.2.0)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (7.0.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (3.12.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: pydot<2,>=1.2.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: orjson<4.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (3.8.0)
# Requirement already satisfied: grpcio<2,>=1.33.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (1.34.1)
# Requirement already satisfied: protobuf<4,>=3.12.2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (3.19.5)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from apache-beam->object-detection==0.1) (0.20.4)
# Requirement already satisfied: kiwisolver>=1.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from matplotlib->object-detection==0.1) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from matplotlib->object-detection==0.1) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from matplotlib->object-detection==0.1) (4.37.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.27.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow_io->object-detection==0.1) (0.27.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: docopt in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.12)
# Requirement already satisfied: python-slugify in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.4)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (65.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (22.9.24)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.12.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.10.1)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: pywin32>=226 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from portalocker->sacrebleu<=2.2.0->object-detection==0.1) (302)
# Requirement already satisfied: scikit-learn>=0.21.3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: typeguard>=2.7 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.13.3)
# Requirement already satisfied: promise in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: etils[epath] in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.8.0)
# Requirement already satisfied: importlib-resources in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.2.0)
# Requirement already satisfied: toml in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: tensorflow-metadata in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from astunparse>=1.6.0->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.2)
# Requirement already satisfied: zipp in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from etils[epath]->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.8.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (4.12.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\envs\obj_det_tf2_cpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow~=2.10.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.1)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1666245 sha256=e0a89927fccda47340233b0f99206b3dce52f2463f7296f2c46d3dc91aead6d5
#   Stored in directory: C:\Users\CYCHEN38\AppData\Local\Temp\pip-ephem-wheel-cache-4qaabuzr\wheels\10\31\16\9268b8b14ff0bee0ea5117af22f7b50e61d3cb59d3c1e50130
# Successfully built object-detection
# Installing collected packages: tf-models-official, object-detection
# Successfully installed object-detection-0.1 tf-models-official-2.10.1
#
# Change back working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu
# fix protobuf builder.py

# %% [markdown]
# # Test your Installation

# %%
import os
cwd = os.getcwd()
print("Current working directory: {0}".format(cwd))
new_path = os.path.join(cwd, "models", "research")
print("New working directory: {0}".format(new_path))
os.chdir(new_path)

##
# !python object_detection/builders/model_builder_tf2_test.py.

os.chdir(cwd)
print("Change back working directory: {0}".format(cwd))
# Out:
# Current working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu
# New working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu\models\research
# Change back working directory: C:\Users\CYCHEN38\image_detection\setup_test\tf2_object_detection_nu
# 2022-12-02 14:19:46.143757: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-12-02 14:19:46.143805: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-02 14:19:53.095828: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-12-02 14:19:53.095856: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-02 14:19:53.097747: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: CONBE03493
# 2022-12-02 14:19:53.097803: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: CONBE03493
# Running tests under Python 3.8.13: C:\ProgramData\Anaconda3\envs\obj_det_tf2_cpu\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-12-02 14:19:53.106438: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# C:\ProgramData\Anaconda3\envs\obj_det_tf2_cpu\lib\site-packages\object_detection\builders\model_builder.py:1109: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W1202 14:19:53.482338  2608 model_builder.py:1109] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.83s
# I1202 14:19:53.932144  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 0.83s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.65s
# I1202 14:19:55.583765  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 1.65s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.37s
# I1202 14:19:55.952786  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.37s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.37s
# I1202 14:19:56.321809  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.37s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.84s
# I1202 14:19:59.163310  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.84s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I1202 14:19:59.169255  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.18s
# I1202 14:19:59.351771  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.18s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.03s
# I1202 14:19:59.379696  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I1202 14:19:59.402637  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.15s
# I1202 14:19:59.551240  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.13s
# I1202 14:19:59.683890  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.13s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.15s
# I1202 14:19:59.831498  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.15s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# I1202 14:19:59.972126  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.14s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.19s
# I1202 14:20:00.165611  2608 test_util.py:2460] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.19s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0