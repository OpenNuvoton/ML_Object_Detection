# %% [markdown]
# # TensorFlow1 Object Detection Env Creating
# ---
# - This install procedure is reference from [here](https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html), which has more detail, but this notebook help you create this env more easily.
# - Before install this, user should follow `readme.md` and install TensorFlow2 version object detection first (check `create_conda_env_tf2.ipynb`).

# %% [markdown]
# # The structure of `tf2_object_detection_nu`
# ---
# - What this directory looks like:
# - <pre>tf2_object_detection_nu/
# ├─ image_dataset/
# |    └─...
# ├─ models/
# |    └─...
# ├─ preTrainModelUsed/
# |    └─...
# ├─ tool/
# |    └─...
# ├─ workspace/
# |    └─...
# ├─ create_conda_env_tf1.ipynb (*we are here)
# ├─ create_conda_env_tf2.ipynb
# ├─ setup_objdet_tf1.ipynb
# ├─ setup_objdet_tf2.ipynb
# ├─ tf1_cpu.yml
# ├─ tf2_cpu.yml
# └─ ...
# </pre>
# - (IMPORTANT) Please remain this notebook at the original directory sequence, because the following commands need the relative location.

# %% [markdown]
# ## TensorFlow Model Garden
# - If you are opening this notebook, you should already download this object detection api. You can skip this step.
# - TensorFlow Model Garden is already prepared in this directory.

# %% [markdown]
# ## Alternative way to download newest TensorFlow Model Garden
# - How to download and prepare it from Google's tutorial is [here](https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/install.html#downloading-the-tensorflow-model-garden). After you download finish, replace the `models/` as new one.

# %% [markdown]
# # Create Tensorflow1 object detection env
# ---
# - Create a virtual env and preinstall some needed libraries at once.

# %%
# !conda env create -f tf1_cpu.yml
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['C:\\ProgramData\\anaconda3\\envs\\obj_det_tf1_cpu\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'C:\\Users\\USER\\Desktop\\ML_tf2_object_detection_nu\\condaenv.rqmdrqry.requirements.txt']
# Pip subprocess output:
# Collecting absl-py==1.3.0
#
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
#
# Collecting astor==0.8.1
#
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
#
# Collecting contextlib2==21.6.0
#
#   Using cached contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
#
# Collecting cycler==0.11.0
#
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
#
# Collecting cython==0.29.32
#
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
#
# Collecting fonttools==4.38.0
#
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
#
# Collecting gast==0.2.2
#
#   Using cached gast-0.2.2-py3-none-any.whl
#
# Collecting google-pasta==0.2.0
#
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
#
# Collecting grpcio==1.50.0
#
#   Using cached grpcio-1.50.0-cp37-cp37m-win_amd64.whl (3.6 MB)
#
# Collecting h5py==2.10.0
#
#   Using cached h5py-2.10.0-cp37-cp37m-win_amd64.whl (2.5 MB)
#
# Collecting importlib-metadata==5.0.0
#
#   Using cached importlib_metadata-5.0.0-py3-none-any.whl (21 kB)
#
# Collecting ipyfilechooser==0.6.0
#
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
#
# Collecting keras-applications==1.0.8
#
#   Using cached Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#
# Collecting keras-preprocessing==1.1.2
#
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#
# Collecting kiwisolver==1.4.4
#
#   Using cached kiwisolver-1.4.4-cp37-cp37m-win_amd64.whl (54 kB)
#
# Collecting lvis==0.5.3
#
#   Using cached lvis-0.5.3-py3-none-any.whl (14 kB)
#
# Collecting lxml==4.9.1
#
#   Using cached lxml-4.9.1-cp37-cp37m-win_amd64.whl (3.6 MB)
#
# Collecting markdown==3.4.1
#
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
#
# Collecting matplotlib==3.5.3
#
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
#
# Collecting numpy==1.18.5
#
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
#
# Collecting opencv-python==4.6.0.66
#
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#
# Collecting opt-einsum==3.3.0
#
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#
# Collecting pandas==1.3.5
#
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
#
# Collecting pillow==9.2.0
#
#   Using cached Pillow-9.2.0-cp37-cp37m-win_amd64.whl (3.3 MB)
#
# Collecting protobuf==3.20.3
#
#   Using cached protobuf-3.20.3-cp37-cp37m-win_amd64.whl (905 kB)
#
# Collecting py-setenv==1.1.0
#
#   Using cached py_setenv-1.1.0-py3-none-any.whl
#
# Collecting regex==2022.9.13
#
#   Using cached regex-2022.9.13-cp37-cp37m-win_amd64.whl (267 kB)
#
# Collecting scipy==1.7.3
#
#   Using cached scipy-1.7.3-cp37-cp37m-win_amd64.whl (34.1 MB)
#
# Collecting setuptools==65.5.0
#
#   Using cached setuptools-65.5.0-py3-none-any.whl (1.2 MB)
#
# Collecting tensorboard==1.15.0
#
#   Using cached tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#
# Collecting tensorflow==1.15.5
#
#   Using cached tensorflow-1.15.5-cp37-cp37m-win_amd64.whl (55.3 MB)
#
# Collecting tensorflow-estimator==1.15.1
#
#   Using cached tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#
# Collecting termcolor==2.0.1
#
#   Using cached termcolor-2.0.1-py3-none-any.whl (5.4 kB)
#
# Collecting tf-slim==1.1.0
#
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#
# Collecting typing-extensions==4.4.0
#
#   Using cached typing_extensions-4.4.0-py3-none-any.whl (26 kB)
#
# Collecting werkzeug==2.2.2
#
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#
# Requirement already satisfied: wheel==0.37.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from -r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 37)) (0.37.1)
#
# Collecting wrapt==1.14.1
#
#   Using cached wrapt-1.14.1-cp37-cp37m-win_amd64.whl (35 kB)
#
# Collecting zipp==3.10.0
#
#   Using cached zipp-3.10.0-py3-none-any.whl (6.2 kB)
#
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from google-pasta==0.2.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 8)) (1.16.0)
#
# Collecting ipywidgets
#
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
#
# Requirement already satisfied: pyparsing>=2.4.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from lvis==0.5.3->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 16)) (3.0.9)
#
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from lvis==0.5.3->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 16)) (2.8.2)
#
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from matplotlib==3.5.3->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 19)) (21.3)
#
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from pandas==1.3.5->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 23)) (2022.1)
#
# Collecting click>=7.0
#
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
#
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from werkzeug==2.2.2->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 36)) (2.1.1)
#
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from click>=7.0->py-setenv==1.1.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 26)) (0.4.5)
#
# Requirement already satisfied: traitlets>=4.3.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (5.1.1)
#
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (6.15.2)
#
# Collecting widgetsnbextension~=4.0
#
#   Using cached widgetsnbextension-4.0.5-py3-none-any.whl (2.0 MB)
#
# Collecting jupyterlab-widgets~=3.0
#
#   Using cached jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
#
# Requirement already satisfied: ipython>=6.1.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (7.31.1)
#
# Requirement already satisfied: debugpy>=1.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (1.5.1)
#
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (23.2.0)
#
# Requirement already satisfied: tornado>=6.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (6.2)
#
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (5.9.0)
#
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (7.3.5)
#
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (1.5.5)
#
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.1.6)
#
# Requirement already satisfied: decorator in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (5.1.1)
#
# Requirement already satisfied: backcall in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.2.0)
#
# Requirement already satisfied: pygments in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (2.11.2)
#
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.18.1)
#
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (3.0.20)
#
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.7.5)
#
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.8.3)
#
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.4)
#
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (4.11.1)
#
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (0.2.5)
#
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\envs\obj_det_tf1_cpu\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser==0.6.0->-r C:\Users\USER\Desktop\ML_tf2_object_detection_nu\condaenv.rqmdrqry.requirements.txt (line 12)) (302)
#
# Installing collected packages: tensorflow-estimator, zipp, wrapt, widgetsnbextension, werkzeug, typing-extensions, termcolor, setuptools, regex, protobuf, pillow, numpy, lxml, jupyterlab-widgets, grpcio, google-pasta, gast, fonttools, cython, cycler, contextlib2, astor, absl-py, tf-slim, scipy, pandas, opt-einsum, opencv-python, kiwisolver, keras-preprocessing, importlib-metadata, h5py, matplotlib, markdown, keras-applications, click, tensorboard, py-setenv, lvis, ipywidgets, tensorflow, ipyfilechooser
#
#   Attempting uninstall: zipp
#
#     Found existing installation: zipp 3.11.0
#
#     Uninstalling zipp-3.11.0:
#
#       Successfully uninstalled zipp-3.11.0
#
#   Attempting uninstall: typing-extensions
#
#     Found existing installation: typing_extensions 4.3.0
#
#     Uninstalling typing_extensions-4.3.0:
#
#       Successfully uninstalled typing_extensions-4.3.0
#
#   Attempting uninstall: setuptools
#
#     Found existing installation: setuptools 65.6.3
#
#     Uninstalling setuptools-65.6.3:
#
#       Successfully uninstalled setuptools-65.6.3
#
#   Attempting uninstall: importlib-metadata
#
#     Found existing installation: importlib-metadata 4.11.3
#
#     Uninstalling importlib-metadata-4.11.3:
#
#       Successfully uninstalled importlib-metadata-4.11.3
#
# Successfully installed absl-py-1.3.0 astor-0.8.1 click-8.1.3 contextlib2-21.6.0 cycler-0.11.0 cython-0.29.32 fonttools-4.38.0 gast-0.2.2 google-pasta-0.2.0 grpcio-1.50.0 h5py-2.10.0 importlib-metadata-5.0.0 ipyfilechooser-0.6.0 ipywidgets-8.0.4 jupyterlab-widgets-3.0.5 keras-applications-1.0.8 keras-preprocessing-1.1.2 kiwisolver-1.4.4 lvis-0.5.3 lxml-4.9.1 markdown-3.4.1 matplotlib-3.5.3 numpy-1.18.5 opencv-python-4.6.0.66 opt-einsum-3.3.0 pandas-1.3.5 pillow-9.2.0 protobuf-3.20.3 py-setenv-1.1.0 regex-2022.9.13 scipy-1.7.3 setuptools-65.5.0 tensorboard-1.15.0 tensorflow-1.15.5 tensorflow-estimator-1.15.1 termcolor-2.0.1 tf-slim-1.1.0 typing-extensions-4.4.0 werkzeug-2.2.2 widgetsnbextension-4.0.5 wrapt-1.14.1 zipp-3.10.0
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate obj_det_tf1_cpu
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 22.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# # Add the Environment Variables
# - This part is done at `create_conda_env_tf2.ipynb`. If you didn't add this, please refer to it.

# %% [markdown]
# # Active this new env
# - Close this JupyterLab now.
# - Close the Anaconda and open it again with administrators.
# - Choose the new env as below picture.
# - Open again the JupyterLab, and now you can install/run the following program in `obj_det_tf2_cpu` env.
# - Open the next for the following install.
# - <img src="tool/choose_new_env.png" width="800" height="500">
